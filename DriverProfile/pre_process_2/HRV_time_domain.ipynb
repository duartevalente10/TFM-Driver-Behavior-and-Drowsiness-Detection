# %%
import pyedflib
import neurokit2 as nk
import pandas as pd
import os

# %% [markdown]
# ## Data

# %%
# Directory of EDF files
edf_directory = '../datasetsPart2/valu3s/vitaport/'

# %%
# Directory of CSV files
csv_directory = '../datasets_2/valu3s/vitaport/filtered_signals/'

# %%
# Duration of each interval in seconds
interval_duration = 120

# Initialize an empty DataFrame to store all features
feature_dfs = []

# Sampling Rate
sampling_rate = 256

# %% [markdown]
# ## Process Data EDF File

# %%
# Function extract featrures from ECG
def extract_hrv_features(signal, sampling_rate, interval_duration):
    # number of intrevals
    interval_samples = int(interval_duration * sampling_rate)
    features = [] 
    
    # loop to extract features for each intreval 
    for start in range(0, len(signal), interval_samples):
        end = start + interval_samples
        if end > len(signal):
            break
        
        interval_signal = signal[start:end]
        if len(interval_signal) < interval_samples:
            continue
        
        try:
            # extract features 
            signals, info = nk.ecg_process(interval_signal, sampling_rate=sampling_rate)
            hrv_features = nk.hrv_time(info['ECG_R_Peaks'], sampling_rate=sampling_rate)
            hrv_features['Interval_Start'] = start / sampling_rate
            hrv_features['Interval_End'] = end / sampling_rate

            # add extrated features to the DataFrame
            features.append(hrv_features)
        except Exception as e:
            print(f"Error processing interval {start}-{end}: {e}")
            continue

    return features

# Loop through all .edf files in the directory
for filename in os.listdir(edf_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(edf_directory, filename)
        
        # Load durations and ECG .csv file
        durations = pd.read_csv('datasets/hrv/filtered_ECG_duration.csv')
        f = pd.read_csv(file_path)
        #Load the .edf file
        f = pyedflib.EdfReader(file_path)
        
        # Get signal labels and find ECG signal index
        signal_labels = f.getSignalLabels()
        if 'ECG' in signal_labels:
            ecg_signal_index = signal_labels.index('ECG')
            ecg_signal = f.readSignal(ecg_signal_index)
            sampling_rate = f.getSampleFrequency(ecg_signal_index)
        else:
            print(f"No ECG signal found in {filename}")
            continue
        
        # Close the EDF file
        f.close()

        # duration of the ECG signal in seconds
        ecg_duration = len(ecg_signal) / sampling_rate
        print(f"ECG duration for {filename}: {ecg_duration} seconds")
        
        # Extract HRV features for each interval
        interval_features = extract_hrv_features(ecg_signal, sampling_rate, interval_duration)

        # number of intervals
        num_intervals = len(interval_features)
        print(f"Number of intervals for {filename}: {num_intervals}")
        
        if interval_features:
            # Convert list of feature dictionaries to DataFrame and add filename
            interval_features_df = pd.concat([pd.DataFrame(features) for features in interval_features])
            interval_features_df['Filename'] = filename
        
            # Append the features DataFrame to the list
            feature_dfs.append(interval_features_df)
        else:
            print(f"No valid intervals found in {filename}")
# Out:
# -0.9713076923076923    float64
# dtype: object
#    -0.9713076923076923
# 0            -0.163328
# 1             2.731728
# 2             0.244323
# 3            -0.841933
# 4            -2.228436
# -0.9713076923076923   -0.163328
# Name: 0, dtype: float64
# ECG duration for fp01_1.csv: 3694.6 seconds
# 1.1230923076923076    float64
# dtype: object
#    1.1230923076923076
# 0            1.088918
# 1            0.197944
# 2           -1.635267
# 3            0.110067
# 4            0.710559
# 1.1230923076923076    1.088918
# Name: 0, dtype: float64
# ECG duration for fp01_2.csv: 3576.7 seconds
# -1.259348717948718    float64
# dtype: object
#    -1.259348717948718
# 0           -0.627123
# 1           -0.048600
# 2            1.420897
# 3            0.041718
# 4           -0.871226
# -1.259348717948718   -0.627123
# Name: 0, dtype: float64
# ECG duration for fp01_3.csv: 3574.1 seconds
# -0.21214871794871798    float64
# dtype: object
#    -0.21214871794871798
# 0              0.146682
# 1              0.061246
# 2             -0.204826
# 3             -0.783349
# 4             -0.236559
# -0.21214871794871798    0.146682
# Name: 0, dtype: float64
# ECG duration for fp01_4.csv: 3734.5 seconds
# 0.17841538461538456    float64
# dtype: object
#    0.17841538461538456
# 0            -0.082774
# 1            -0.182856
# 2            -0.556333
# 3            -0.209708
# 4             0.158887
# 0.17841538461538456   -0.082774
# Name: 0, dtype: float64
# ECG duration for fp02_1.csv: 3721.4 seconds
# -0.08277435897435902    float64
# dtype: object
#    -0.08277435897435902
# 0             -0.151123
# 1             -0.378138
# 2             -0.080333
# 3              0.310231
# 4             -0.024190
# -0.08277435897435902   -0.151123
# Name: 0, dtype: float64
# ECG duration for fp02_2.csv: 3691.2 seconds
# 0.15400512820512816    float64
# dtype: object
#    0.15400512820512816
# 0             0.229677
# 1             0.393226
# 2             0.244323
# 3             0.205267
# 4             0.175974
# 0.15400512820512816    0.229677
# Name: 0, dtype: float64
# ECG duration for fp02_3.csv: 3575.1 seconds
# -0.10230256410256414    float64
# dtype: object
#    -0.10230256410256414
# 0             -0.131595
# 1             -0.160887
# 2             -0.102303
# 3              0.000221
# 4             -0.092538
# -0.10230256410256414   -0.131595
# Name: 0, dtype: float64
# ECG duration for fp02_4.csv: 3668.9 seconds
# 1.1011230769230769    float64
# dtype: object
#    1.1011230769230769
# 0            0.551892
# 1           -1.491246
# 2           -0.448928
# 3            0.737410
# 4            1.647913
# 1.1011230769230769    0.551892
# Name: 0, dtype: float64
# ECG duration for fp03_2.csv: 3990.5 seconds
# -0.1657692307692308    float64
# dtype: object
#    -0.1657692307692308
# 0            -0.021749
# 1             0.271174
# 2             0.056364
# 3            -0.036395
# 4            -0.202385
# -0.1657692307692308   -0.021749
# Name: 0, dtype: float64
# ECG duration for fp03_3.csv: 3580.9 seconds
# -0.15844615384615388    float64
# dtype: object
#    -0.15844615384615388
# 0              0.412754
# 1             -0.180415
# 2             -0.688149
# 3             -0.375697
# 4             -0.158446
# -0.15844615384615388    0.412754
# Name: 0, dtype: float64
# ECG duration for fp03_4.csv: 3573.3 seconds
# -0.42451794871794873    float64
# dtype: object
#    -0.42451794871794873
# 0             -0.177974
# 1              0.420077
# 2             -0.109626
# 3             -0.224354
# 4             -0.685708
# -0.42451794871794873   -0.177974
# Name: 0, dtype: float64
# ECG duration for fp04_1.csv: 3983.6 seconds
# -0.5709794871794872    float64
# dtype: object
#    -0.5709794871794872
# 0            -0.214590
# 1            -0.016867
# 2             0.554333
# 3             0.027072
# 4            -0.473338
# -0.5709794871794872   -0.21459
# Name: 0, dtype: float64
# ECG duration for fp04_2.csv: 3580.7 seconds
# -0.9127230769230769    float64
# dtype: object
#    -0.9127230769230769
# 0            -0.668621
# 1            -0.932251
# 2            -1.566918
# 3            -0.758938
# 4            -0.519718
# -0.9127230769230769   -0.668621
# Name: 0, dtype: float64
# ECG duration for fp04_3.csv: 3570.8 seconds
# 0.13447692307692302    float64
# dtype: object
#    0.13447692307692302
# 0             0.017308
# 1            -0.275615
# 2            -0.029072
# 3             0.122272
# 4             0.217472
# 0.13447692307692302    0.017308
# Name: 0, dtype: float64
# ECG duration for fp04_4.csv: 3575.2 seconds
# -1.8671641025641026    float64
# dtype: object
#    -1.8671641025641026
# 0            -2.055123
# 1            -2.138118
# 2            -1.945277
# 3            -1.603533
# 4            -1.310610
# -1.8671641025641026   -2.055123
# Name: 0, dtype: float64
# ECG duration for fp05_1.csv: 3891.8 seconds
# 0.036835897435897394    float64
# dtype: object
#    0.036835897435897394
# 0             -0.004662
# 1             -0.068128
# 2             -0.060805
# 3              0.002662
# 4              0.056364
# 0.036835897435897394   -0.004662
# Name: 0, dtype: float64
# ECG duration for fp05_2.csv: 3574.3 seconds
# 0.10518461538461533    float64
# dtype: object
#    0.10518461538461533
# 0             0.588508
# 1             0.197944
# 2            -0.439164
# 3            -0.314672
# 4            -0.094979
# 0.10518461538461533    0.588508
# Name: 0, dtype: float64
# ECG duration for fp05_3.csv: 3606.8 seconds
# 0.263851282051282    float64
# dtype: object
#    0.263851282051282
# 0          -0.334200
# 1          -0.016867
# 2           0.183297
# 3           0.617800
# 4           0.327318
# 0.263851282051282   -0.3342
# Name: 0, dtype: float64
# ECG duration for fp05_4.csv: 3573.2 seconds
# -4.999    float64
# dtype: object
#      -4.999
# 0 -4.872067
# 1 -0.900518
# 2  4.997000
# 3  2.023831
# 4 -3.502651
# -4.999   -4.872067
# Name: 0, dtype: float64
# ECG duration for fp06_1.csv: 4004.4 seconds
# 1.2549076923076923    float64
# dtype: object
#    1.2549076923076923
# 0           -3.126733
# 1           -4.388744
# 2           -0.744292
# 3            4.997000
# 4            1.618621
# 1.2549076923076923   -3.126733
# Name: 0, dtype: float64
# ECG duration for fp06_2.csv: 3574.9 seconds
# 4.997    float64
# dtype: object
#       4.997
# 0  1.560036
# 1 -3.778487
# 2 -4.300867
# 3 -0.900518
# 4  4.997000
# 4.997    1.560036
# Name: 0, dtype: float64
# ECG duration for fp06_3.csv: 3572.3 seconds
# -1.5766820512820512    float64
# dtype: object
#    -1.5766820512820512
# 0            -4.886713
# 1            -1.007923
# 2             4.997000
# 3             2.158087
# 4            -0.268292
# -1.5766820512820512   -4.886713
# Name: 0, dtype: float64
# ECG duration for fp06_4.csv: 3572.6 seconds
# -0.5758615384615384    float64
# dtype: object
#    -0.5758615384615384
# 0            -0.055923
# 1             0.056364
# 2             0.471338
# 3            -0.014426
# 4            -0.658856
# -0.5758615384615384   -0.055923
# Name: 0, dtype: float64
# ECG duration for fp07_1.csv: 3698.4 seconds
# 0.36881538461538454    float64
# dtype: object
#    0.36881538461538454
# 0             0.036836
# 1            -0.033954
# 2            -0.353728
# 3            -0.031513
# 4             0.322436
# 0.36881538461538454    0.036836
# Name: 0, dtype: float64
# ECG duration for fp07_2.csv: 3606.5 seconds
# 0.039276923076923036    float64
# dtype: object
#    0.039276923076923036
# 0             -0.043718
# 1             -0.177974
# 2             -0.063246
# 3             -0.031513
# 4              0.036836
# 0.039276923076923036   -0.043718
# Name: 0, dtype: float64
# ECG duration for fp07_3.csv: 3578.3 seconds
# -0.0705692307692308    float64
# dtype: object
#    -0.0705692307692308
# 0             0.046600
# 1            -0.004662
# 2             0.263851
# 3             0.056364
# 4             0.029513
# -0.0705692307692308    0.0466
# Name: 0, dtype: float64
# ECG duration for fp07_4.csv: 3582.4 seconds
# -0.20726666666666668    float64
# dtype: object
#    -0.20726666666666668
# 0             -0.219472
# 1             -0.099862
# 2              0.092979
# 3              0.090538
# 4             -0.175533
# -0.20726666666666668   -0.219472
# Name: 0, dtype: float64
# ECG duration for fp08_1.csv: 3938.9 seconds
# 0.14179999999999995    float64
# dtype: object
#    0.14179999999999995
# 0            -0.002221
# 1            -0.051041
# 2             0.036836
# 3             0.061246
# 4             0.146682
# 0.14179999999999995   -0.002221
# Name: 0, dtype: float64
# ECG duration for fp08_2.csv: 3571.8 seconds
# 0.43960512820512815    float64
# dtype: object
#    0.43960512820512815
# 0             0.114949
# 1             0.063687
# 2            -0.246323
# 3            -0.007103
# 4             0.232118
# 0.43960512820512815    0.114949
# Name: 0, dtype: float64
# ECG duration for fp08_3.csv: 3572.1 seconds
# -0.24632307692307695    float64
# dtype: object
#    -0.24632307692307695
# 0             -0.148682
# 1              0.327318
# 2             -0.031513
# 3             -0.331759
# 4             -0.231677
# -0.24632307692307695   -0.148682
# Name: 0, dtype: float64
# ECG duration for fp08_4.csv: 3571.3 seconds
# 0.02463076923076919    float64
# dtype: object
#    0.02463076923076919
# 0             0.141800
# 1            -0.016867
# 2            -0.026631
# 3            -0.090097
# 4             0.031954
# 0.02463076923076919    0.1418
# Name: 0, dtype: float64
# ECG duration for fp09_1.csv: 3876.1 seconds
# -0.011984615384615425    float64
# dtype: object
#    -0.011984615384615425
# 0               0.110067
# 1               0.188179
# 2               0.405431
# 3               0.229677
# 4               0.058805
# -0.011984615384615425    0.110067
# Name: 0, dtype: float64
# ECG duration for fp09_2.csv: 3569.1 seconds
# 0.28582051282051274    float64
# dtype: object
#    0.28582051282051274
# 0             0.217472
# 1             0.110067
# 2             0.234559
# 3             0.422518
# 4             0.266292
# 0.28582051282051274    0.217472
# Name: 0, dtype: float64
# ECG duration for fp09_3.csv: 3574.9 seconds
# 0.16376923076923072    float64
# dtype: object
#    0.16376923076923072
# 0             0.173533
# 1             0.173533
# 2             0.163769
# 3             0.168651
# 4             0.173533
# 0.16376923076923072    0.173533
# Name: 0, dtype: float64
# ECG duration for fp09_4.csv: 3577.2 seconds
# 0.049041025641025596    float64
# dtype: object
#    0.049041025641025596
# 0              0.049041
# 1              0.051482
# 2              0.041718
# 3              0.041718
# 4              0.046600
# 0.049041025641025596    0.049041
# Name: 0, dtype: float64
# ECG duration for fp10_1.csv: 3789.4 seconds
# 0.28582051282051274    float64
# dtype: object
#    0.28582051282051274
# 0             0.166210
# 1             0.307790
# 2             0.307790
# 3             0.383462
# 4             0.256528
# 0.28582051282051274    0.16621
# Name: 0, dtype: float64
# ECG duration for fp10_2.csv: 3579.2 seconds
# 0.3224358974358974    float64
# dtype: object
#    0.3224358974358974
# 0            0.237000
# 1            0.036836
# 2           -0.429400
# 3           -0.097421
# 4            0.080774
# 0.3224358974358974    0.237
# Name: 0, dtype: float64
# ECG duration for fp10_3.csv: 3575.7 seconds
# -0.8126410256410256    float64
# dtype: object
#    -0.8126410256410256
# 0            -0.217031
# 1            -0.099862
# 2             0.217472
# 3            -0.212149
# 4            -0.812641
# -0.8126410256410256   -0.217031
# Name: 0, dtype: float64
# ECG duration for fp10_4.csv: 3570.6 seconds
# 0.05148205128205124    float64
# dtype: object
#    0.05148205128205124
# 0             0.322436
# 1             0.800877
# 2             0.202826
# 3            -0.656415
# 4            -0.104744
# 0.05148205128205124    0.322436
# Name: 0, dtype: float64
# ECG duration for fp11_1.csv: 3718.1 seconds
# -0.20482564102564105    float64
# dtype: object
#    -0.20482564102564105
# 0             -1.149503
# 1             -0.102303
# 2              1.201205
# 3              0.288262
# 4             -0.082774
# -0.20482564102564105   -1.149503
# Name: 0, dtype: float64
# ECG duration for fp11_2.csv: 3573.8 seconds
# -0.4269589743589744    float64
# dtype: object
#    -0.4269589743589744
# 0            -0.368374
# 1            -0.094979
# 2             0.459133
# 3            -0.036395
# 4            -0.224354
# -0.4269589743589744   -0.368374
# Name: 0, dtype: float64
# ECG duration for fp11_3.csv: 3573.7 seconds
# -0.28782051282051285    float64
# dtype: object
#    -0.28782051282051285
# 0             -0.317113
# 1             -0.114508
# 2              0.280938
# 3             -0.046159
# 4             -0.217031
# -0.28782051282051285   -0.317113
# Name: 0, dtype: float64
# ECG duration for fp11_4.csv: 3575.7 seconds
# 2.4827435897435897    float64
# dtype: object
#    2.4827435897435897
# 0            0.525041
# 1           -1.193441
# 2           -3.502651
# 3           -2.250405
# 4           -1.230056
# 2.4827435897435897    0.525041
# Name: 0, dtype: float64
# ECG duration for fp12_1.csv: 3835.7 seconds
# -2.2015846153846153    float64
# dtype: object
#    -2.2015846153846153
# 0            -1.122651
# 1             1.848077
# 2            -0.629564
# 3            -2.658056
# 4            -1.418015
# -2.2015846153846153   -1.122651
# Name: 0, dtype: float64
# ECG duration for fp12_2.csv: 3576.6 seconds
# -3.3806    float64
# dtype: object
#     -3.3806
# 0  0.012426
# 1  4.997000
# 2  0.444487
# 3 -0.280497
# 4 -4.076292
# -3.3806    0.012426
# Name: 0, dtype: float64
# ECG duration for fp12_3.csv: 3572.8 seconds
# -0.7101179487179488    float64
# dtype: object
#    -0.7101179487179488
# 0            -0.248764
# 1             0.112508
# 2            -0.021749
# 3            -0.129154
# 4            -0.436723
# -0.7101179487179488   -0.248764
# Name: 0, dtype: float64
# ECG duration for fp12_4.csv: 3578.3 seconds
# 0.6300051282051281    float64
# dtype: object
#    0.6300051282051281
# 0            0.022190
# 1           -0.099862
# 2           -0.451369
# 3            0.056364
# 4            0.678826
# 0.6300051282051281    0.02219
# Name: 0, dtype: float64
# ECG duration for fp13_1.csv: 3860.4 seconds
# -2.65805641025641    float64
# dtype: object
#    -2.65805641025641
# 0          -4.999000
# 1           2.126354
# 2           4.997000
# 3           3.551913
# 4          -2.533564
# -2.65805641025641   -4.999
# Name: 0, dtype: float64
# ECG duration for fp13_2.csv: 3573.6 seconds
# 4.997    float64
# dtype: object
#       4.997
# 0 -0.729646
# 1 -4.425359
# 2 -4.999000
# 3  4.997000
# 4  4.997000
# 4.997   -0.729646
# Name: 0, dtype: float64
# ECG duration for fp13_3.csv: 3590.2 seconds
# 4.997    float64
# dtype: object
#       4.997
# 0  3.439626
# 1 -2.404190
# 2 -4.999000
# 3  4.997000
# 4  4.997000
# 4.997    3.439626
# Name: 0, dtype: float64
# ECG duration for fp13_4.csv: 3573.9 seconds
# 0.02463076923076919    float64
# dtype: object
#    0.02463076923076919
# 0             0.022190
# 1             0.029513
# 2             0.031954
# 3             0.024631
# 4             0.036836
# 0.02463076923076919    0.02219
# Name: 0, dtype: float64
# ECG duration for fp14_1.csv: 3906.7 seconds
# 0.08321538461538457    float64
# dtype: object
#    0.08321538461538457
# 0             0.019749
# 1            -0.168210
# 2             0.046600
# 3             0.205267
# 4             0.117390
# 0.08321538461538457    0.019749
# Name: 0, dtype: float64
# ECG duration for fp14_2.csv: 3570.6 seconds
# 0.009984615384615342    float64
# dtype: object
#    0.009984615384615342
# 0              0.019749
# 1              0.009985
# 2              0.012426
# 3              0.012426
# 4              0.000221
# 0.009984615384615342    0.019749
# Name: 0, dtype: float64
# ECG duration for fp14_3.csv: 4214.1 seconds
# -0.5026307692307692    float64
# dtype: object
#    -0.5026307692307692
# 0            -0.026631
# 1             1.450190
# 2             0.034395
# 3            -1.337462
# 4            -0.607595
# -0.5026307692307692   -0.026631
# Name: 0, dtype: float64
# ECG duration for fp14_4.csv: 3570.7 seconds
# 1.5063333333333333    float64
# dtype: object
#    1.5063333333333333
# 0            1.762641
# 1            1.652795
# 2            1.303728
# 3            0.573862
# 4           -0.400108
# 1.5063333333333333    1.762641
# Name: 0, dtype: float64
# ECG duration for fp15_1.csv: 3671.4 seconds
# -0.46113333333333334    float64
# dtype: object
#    -0.46113333333333334
# 0             -0.173092
# 1              0.695913
# 2             -0.121831
# 3             -0.822405
# 4             -0.578303
# -0.46113333333333334   -0.173092
# Name: 0, dtype: float64
# ECG duration for fp15_2.csv: 3574.4 seconds
# -0.13891794871794874    float64
# dtype: object
#    -0.13891794871794874
# 0             -0.073010
# 1             -0.065687
# 2             -0.080333
# 3             -0.121831
# 4              0.049041
# -0.13891794871794874   -0.07301
# Name: 0, dtype: float64
# ECG duration for fp15_3.csv: 3574.7 seconds
# -0.02174871794871799    float64
# dtype: object
#    -0.02174871794871799
# 0             -0.046159
# 1             -0.011985
# 2              0.012426
# 3              0.034395
# 4              0.017308
# -0.02174871794871799   -0.046159
# Name: 0, dtype: float64
# ECG duration for fp15_4.csv: 3574.4 seconds
# -0.2927025641025641    float64
# dtype: object
#    -0.2927025641025641
# 0            -0.365933
# 1            -0.160887
# 2             0.202826
# 3             0.105185
# 4            -0.104744
# -0.2927025641025641   -0.365933
# Name: 0, dtype: float64
# ECG duration for fp16_1.csv: 3829.7 seconds
# -0.031512820512820554    float64
# dtype: object
#    -0.031512820512820554
# 0              -0.300026
# 1               0.017308
# 2               0.200385
# 3               0.190621
# 4               0.012426
# -0.031512820512820554   -0.300026
# Name: 0, dtype: float64
# ECG duration for fp16_2.csv: 3576.0 seconds
# -0.0461589743589744    float64
# dtype: object
#    -0.0461589743589744
# 0            -0.419636
# 1            -0.165769
# 2            -0.024190
# 3             0.332200
# 4             0.031954
# -0.0461589743589744   -0.419636
# Name: 0, dtype: float64
# ECG duration for fp16_3.csv: 3571.8 seconds
# -0.1730923076923077    float64
# dtype: object
#    -0.1730923076923077
# 0            -0.436723
# 1            -0.475779
# 2            -0.251205
# 3             0.141800
# 4            -0.119390
# -0.1730923076923077   -0.436723
# Name: 0, dtype: float64
# ECG duration for fp16_4.csv: 3572.4 seconds
# -0.016866666666666707    float64
# dtype: object
#    -0.016866666666666707
# 0               0.049041
# 1               0.322436
# 2               0.061246
# 3              -0.075451
# 4              -0.082774
# -0.016866666666666707    0.049041
# Name: 0, dtype: float64
# ECG duration for fp17_1.csv: 3639.7 seconds
# 0.022189743589743547    float64
# dtype: object
#    0.022189743589743547
# 0             -0.011985
# 1             -0.019308
# 2             -0.080333
# 3             -0.036395
# 4              0.005103
# 0.022189743589743547   -0.011985
# Name: 0, dtype: float64
# ECG duration for fp17_2.csv: 3823.6 seconds
# 0.049041025641025596    float64
# dtype: object
#    0.049041025641025596
# 0             -0.392785
# 1             -0.461133
# 2             -0.068128
# 3              0.720323
# 4              0.083215
# 0.049041025641025596   -0.392785
# Name: 0, dtype: float64
# ECG duration for fp17_3.csv: 3574.8 seconds
# -0.1120666666666667    float64
# dtype: object
#    -0.1120666666666667
# 0            -0.902959
# 1            -0.212149
# 2             0.210149
# 3             0.378579
# 4            -0.031513
# -0.1120666666666667   -0.902959
# Name: 0, dtype: float64
# ECG duration for fp17_4.csv: 3743.7 seconds
# -0.07545128205128208    float64
# dtype: object
#    -0.07545128205128208
# 0             -1.623062
# 1             -0.112067
# 2              0.298026
# 3              0.891195
# 4             -0.087656
# -0.07545128205128208   -1.623062
# Name: 0, dtype: float64
# ECG duration for fp18_1.csv: 3813.3 seconds
# -0.06080512820512824    float64
# dtype: object
#    -0.06080512820512824
# 0             -0.073010
# 1             -0.231677
# 2             -0.041277
# 3              0.031954
# 4              0.022190
# -0.06080512820512824   -0.07301
# Name: 0, dtype: float64
# ECG duration for fp18_2.csv: 4069.4 seconds
# -1.1543846153846153    float64
# dtype: object
#    -1.1543846153846153
# 0            -0.563656
# 1            -0.014426
# 2             1.464836
# 3             0.005103
# 4            -0.661297
# -1.1543846153846153   -0.563656
# Name: 0, dtype: float64
# ECG duration for fp18_3.csv: 3573.2 seconds
# -1.6352666666666666    float64
# dtype: object
#    -1.6352666666666666
# 0             0.002662
# 1             1.223174
# 2             0.464015
# 3            -0.085215
# 4            -1.789051
# -1.6352666666666666    0.002662
# Name: 0, dtype: float64
# ECG duration for fp18_4.csv: 3573.1 seconds
# -2.7630205128205128    float64
# dtype: object
#    -2.7630205128205128
# 0            -4.999000
# 1             0.778908
# 2             4.997000
# 3             4.689431
# 4            -0.658856
# -2.7630205128205128   -4.999
# Name: 0, dtype: float64
# ECG duration for fp19_1.csv: 3639.7 seconds
# -0.1486820512820513    float64
# dtype: object
#    -0.1486820512820513
# 0             0.005103
# 1             0.088097
# 2             0.368815
# 3             0.119831
# 4            -0.036395
# -0.1486820512820513    0.005103
# Name: 0, dtype: float64
# ECG duration for fp19_2.csv: 3582.7 seconds
# -0.06080512820512824    float64
# dtype: object
#    -0.06080512820512824
# 0              0.066128
# 1              0.188179
# 2              0.063687
# 3              0.071010
# 4             -0.048600
# -0.06080512820512824    0.066128
# Name: 0, dtype: float64
# ECG duration for fp19_3.csv: 3015.8 seconds
# -0.10962564102564105    float64
# dtype: object
#    -0.10962564102564105
# 0              0.556774
# 1              0.500631
# 2             -0.048600
# 3             -1.039656
# 4             -0.204826
# -0.10962564102564105    0.556774
# Name: 0, dtype: float64
# ECG duration for fp20_1.csv: 3712.1 seconds
# 0.1930615384615384    float64
# dtype: object
#    0.1930615384615384
# 0            0.713000
# 1           -0.065687
# 2           -1.212969
# 3           -0.422077
# 4           -0.019308
# 0.1930615384615384    0.713
# Name: 0, dtype: float64
# ECG duration for fp20_2.csv: 3577.9 seconds
# -0.06812820512820517    float64
# dtype: object
#    -0.06812820512820517
# 0              3.029533
# 1              0.190621
# 2             -1.901338
# 3             -1.730467
# 4             -0.165769
# -0.06812820512820517    3.029533
# Name: 0, dtype: float64
# ECG duration for fp20_3.csv: 3045.8 seconds
# 0.2223538461538461    float64
# dtype: object
#    0.2223538461538461
# 0            0.229677
# 1           -0.041277
# 2           -0.622241
# 3           -0.119390
# 4            0.100303
# 0.2223538461538461    0.229677
# Name: 0, dtype: float64
# ECG duration for fp20_4.csv: 3628.4 seconds

# %% [markdown]
# ## Save Features Dataset EDF

# %%
# Concatenate all feature DataFrames into one DataFrame
all_features_df = pd.concat(feature_dfs, ignore_index=True)

# Save the features DataFrame to a CSV file
all_features_df.to_csv('hrv_time_domain_5_min.csv', index=False)

print("Saved features on 'rv_time_domain_5_min.csv'.")
# Out:
# Saved features on 'rv_time_domain_5_min.csv'.

# %% [markdown]
# ## Process Data CSV File

# %%
# Function to extract features from ECG
def extract_hrv_features(signal, sampling_rate, interval_duration):
    # Number of intervals
    interval_samples = int(interval_duration * sampling_rate)
    features = [] 
    
    # Loop to extract features for each interval 
    for start in range(0, len(signal), interval_samples):
        end = start + interval_samples
        if end > len(signal):
            break
        
        interval_signal = signal[start:end]
        if len(interval_signal) < interval_samples:
            continue
        
        try:
            # Extract features using NeuroKit
            signals, info = nk.ecg_process(interval_signal, sampling_rate=sampling_rate)
            hrv_features = nk.hrv_time(info['ECG_R_Peaks'], sampling_rate=sampling_rate)
            hrv_features['Interval_Start'] = start / sampling_rate
            hrv_features['Interval_End'] = end / sampling_rate

            # Add extracted features to the list
            features.append(hrv_features)
        except Exception as e:
            print(f"Error processing interval {start}-{end}: {e}")
            continue

    return features

# List to store all features from multiple files
feature_dfs = []

# Loop all csv files
for filename in os.listdir(csv_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(csv_directory, filename)
        
        # Load the csv file 
        try:
            # Read csv 
            df = pd.read_csv(file_path, header=None)
            ecg_signal = df[0].values 
        except Exception as e:
            print(f"Error loading {filename}: {e}")
            continue

        # Duration of the ECG signal in seconds
        ecg_duration = len(ecg_signal) / sampling_rate
        print(f"ECG duration for {filename}: {ecg_duration} seconds")
        
        # Extract HRV features for each interval
        interval_features = extract_hrv_features(ecg_signal, sampling_rate, interval_duration)

        # Number of intervals
        num_intervals = len(interval_features)
        print(f"Number of intervals for {filename}: {num_intervals}")
        
        if interval_features:
            # Convert list of feature dictionaries to DataFrame and add filename
            interval_features_df = pd.concat([pd.DataFrame(features) for features in interval_features])
            interval_features_df['Filename'] = filename
        
            # Append the features DataFrame to the list
            feature_dfs.append(interval_features_df)
        else:
            print(f"No valid intervals found in {filename}")
# Out:
# ECG duration for fp01_1.csv: 3694.578125 seconds
# Number of intervals for fp01_1.csv: 30
# ECG duration for fp01_2.csv: 3576.703125 seconds
# Number of intervals for fp01_2.csv: 29
# ECG duration for fp01_3.csv: 3574.078125 seconds
# Number of intervals for fp01_3.csv: 29
# ECG duration for fp01_4.csv: 3734.52734375 seconds
# Number of intervals for fp01_4.csv: 31
# ECG duration for fp02_1.csv: 3721.453125 seconds
# Number of intervals for fp02_1.csv: 31
# ECG duration for fp02_2.csv: 3691.203125 seconds
# Number of intervals for fp02_2.csv: 30
# ECG duration for fp02_3.csv: 3575.078125 seconds
# Number of intervals for fp02_3.csv: 29
# ECG duration for fp02_4.csv: 3668.953125 seconds
# Number of intervals for fp02_4.csv: 30
# ECG duration for fp03_2.csv: 3990.5078125 seconds
# Number of intervals for fp03_2.csv: 33
# ECG duration for fp03_3.csv: 3580.953125 seconds
# Number of intervals for fp03_3.csv: 29
# ECG duration for fp03_4.csv: 3573.328125 seconds
# Number of intervals for fp03_4.csv: 29
# ECG duration for fp04_1.csv: 3983.578125 seconds
# Number of intervals for fp04_1.csv: 33
# ECG duration for fp04_2.csv: 3580.703125 seconds
# Number of intervals for fp04_2.csv: 29
# ECG duration for fp04_3.csv: 3570.828125 seconds
# Number of intervals for fp04_3.csv: 29
# ECG duration for fp04_4.csv: 3575.203125 seconds
# Number of intervals for fp04_4.csv: 29
# ECG duration for fp05_1.csv: 3891.828125 seconds
# Number of intervals for fp05_1.csv: 32
# ECG duration for fp05_2.csv: 3574.328125 seconds
# Number of intervals for fp05_2.csv: 29
# ECG duration for fp05_3.csv: 3606.7578125 seconds
# Number of intervals for fp05_3.csv: 30
# ECG duration for fp05_4.csv: 3573.203125 seconds
# Number of intervals for fp05_4.csv: 29
# ECG duration for fp06_1.csv: 4004.453125 seconds
# Number of intervals for fp06_1.csv: 33
# ECG duration for fp06_2.csv: 3574.953125 seconds
# Number of intervals for fp06_2.csv: 29
# ECG duration for fp06_3.csv: 3572.328125 seconds
# Number of intervals for fp06_3.csv: 29
# ECG duration for fp06_4.csv: 3572.578125 seconds
# Number of intervals for fp06_4.csv: 29
# ECG duration for fp07_1.csv: 3698.453125 seconds
# Number of intervals for fp07_1.csv: 30
# ECG duration for fp07_2.csv: 3606.5078125 seconds
# Number of intervals for fp07_2.csv: 30
# ECG duration for fp07_3.csv: 3578.328125 seconds
# Number of intervals for fp07_3.csv: 29
# ECG duration for fp07_4.csv: 3582.453125 seconds
# Number of intervals for fp07_4.csv: 29
# ECG duration for fp08_1.csv: 3938.953125 seconds
# Number of intervals for fp08_1.csv: 32
# ECG duration for fp08_2.csv: 3571.828125 seconds
# Number of intervals for fp08_2.csv: 29
# ECG duration for fp08_3.csv: 3572.078125 seconds
# Number of intervals for fp08_3.csv: 29
# ECG duration for fp08_4.csv: 3571.328125 seconds
# Number of intervals for fp08_4.csv: 29
# ECG duration for fp09_1.csv: 3876.078125 seconds
# Number of intervals for fp09_1.csv: 32
# ECG duration for fp09_2.csv: 3569.078125 seconds
# Number of intervals for fp09_2.csv: 29
# ECG duration for fp09_3.csv: 3574.953125 seconds
# Number of intervals for fp09_3.csv: 29
# ECG duration for fp09_4.csv: 3577.203125 seconds
# Number of intervals for fp09_4.csv: 29
# ECG duration for fp10_1.csv: 3789.453125 seconds
# Number of intervals for fp10_1.csv: 31
# ECG duration for fp10_2.csv: 3579.20703125 seconds
# Number of intervals for fp10_2.csv: 29
# ECG duration for fp10_3.csv: 3575.703125 seconds
# Number of intervals for fp10_3.csv: 29
# ECG duration for fp10_4.csv: 3570.578125 seconds
# Number of intervals for fp10_4.csv: 29
# ECG duration for fp11_1.csv: 3718.078125 seconds
# Number of intervals for fp11_1.csv: 30
# ECG duration for fp11_2.csv: 3573.828125 seconds
# Number of intervals for fp11_2.csv: 29
# ECG duration for fp11_3.csv: 3573.703125 seconds
# Number of intervals for fp11_3.csv: 29
# ECG duration for fp11_4.csv: 3575.703125 seconds
# Number of intervals for fp11_4.csv: 29
# ECG duration for fp12_1.csv: 3835.703125 seconds
# Number of intervals for fp12_1.csv: 31
# ECG duration for fp12_2.csv: 3576.578125 seconds
# Number of intervals for fp12_2.csv: 29
# ECG duration for fp12_3.csv: 3572.828125 seconds
# Number of intervals for fp12_3.csv: 29
# ECG duration for fp12_4.csv: 3578.328125 seconds
# Number of intervals for fp12_4.csv: 29
# ECG duration for fp13_1.csv: 3860.453125 seconds
# Error processing interval 61440-92160: index 11 is out of bounds for axis 0 with size 9
# Error processing interval 92160-122880: cannot convert float NaN to integer
# Error processing interval 122880-153600: cannot convert float NaN to integer
# Error processing interval 153600-184320: integer division or modulo by zero
# Error processing interval 184320-215040: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 215040-245760: integer division or modulo by zero
# Error processing interval 245760-276480: integer division or modulo by zero
# Error processing interval 276480-307200: integer division or modulo by zero
# Error processing interval 307200-337920: integer division or modulo by zero
# Error processing interval 337920-368640: integer division or modulo by zero
# Error processing interval 368640-399360: integer division or modulo by zero
# Error processing interval 399360-430080: integer division or modulo by zero
# Error processing interval 430080-460800: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 460800-491520: integer division or modulo by zero
# Error processing interval 491520-522240: integer division or modulo by zero
# Error processing interval 522240-552960: integer division or modulo by zero
# Error processing interval 552960-583680: integer division or modulo by zero
# Error processing interval 583680-614400: integer division or modulo by zero
# Error processing interval 614400-645120: integer division or modulo by zero
# Error processing interval 645120-675840: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 675840-706560: integer division or modulo by zero
# Error processing interval 706560-737280: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 737280-768000: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 768000-798720: integer division or modulo by zero
# Error processing interval 798720-829440: integer division or modulo by zero
# Error processing interval 829440-860160: integer division or modulo by zero
# Error processing interval 860160-890880: integer division or modulo by zero
# Error processing interval 890880-921600: integer division or modulo by zero
# Error processing interval 921600-952320: integer division or modulo by zero
# Error processing interval 952320-983040: integer division or modulo by zero
# Number of intervals for fp13_1.csv: 2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# ECG duration for fp13_2.csv: 3573.578125 seconds
# Error processing interval 0-30720: index 9 is out of bounds for axis 0 with size 9
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Error processing interval 30720-61440: cannot convert float NaN to integer
# Error processing interval 61440-92160: integer division or modulo by zero
# Error processing interval 92160-122880: integer division or modulo by zero
# Error processing interval 122880-153600: integer division or modulo by zero
# Error processing interval 153600-184320: integer division or modulo by zero
# Error processing interval 184320-215040: integer division or modulo by zero
# Error processing interval 215040-245760: integer division or modulo by zero
# Error processing interval 245760-276480: integer division or modulo by zero
# Error processing interval 276480-307200: integer division or modulo by zero
# Error processing interval 307200-337920: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 337920-368640: integer division or modulo by zero
# Error processing interval 368640-399360: integer division or modulo by zero
# Error processing interval 399360-430080: integer division or modulo by zero
# Error processing interval 430080-460800: integer division or modulo by zero
# Error processing interval 460800-491520: integer division or modulo by zero
# Error processing interval 491520-522240: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 522240-552960: integer division or modulo by zero
# Error processing interval 552960-583680: integer division or modulo by zero
# Error processing interval 583680-614400: integer division or modulo by zero
# Error processing interval 614400-645120: integer division or modulo by zero
# Error processing interval 645120-675840: integer division or modulo by zero
# Error processing interval 675840-706560: integer division or modulo by zero
# Error processing interval 706560-737280: integer division or modulo by zero
# Error processing interval 737280-768000: integer division or modulo by zero
# Error processing interval 768000-798720: integer division or modulo by zero
# Error processing interval 798720-829440: integer division or modulo by zero
# Error processing interval 829440-860160: integer division or modulo by zero
# Error processing interval 860160-890880: integer division or modulo by zero
# Number of intervals for fp13_2.csv: 0
# No valid intervals found in fp13_2.csv
# ECG duration for fp13_3.csv: 3590.203125 seconds
# Error processing interval 30720-61440: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 61440-92160: cannot convert float NaN to integer
# Error processing interval 92160-122880: integer division or modulo by zero
# Error processing interval 122880-153600: integer division or modulo by zero
# Error processing interval 153600-184320: integer division or modulo by zero
# Error processing interval 184320-215040: integer division or modulo by zero
# Error processing interval 215040-245760: integer division or modulo by zero
# Error processing interval 245760-276480: integer division or modulo by zero
# Error processing interval 276480-307200: integer division or modulo by zero
# Error processing interval 307200-337920: integer division or modulo by zero
# Error processing interval 337920-368640: integer division or modulo by zero
# Error processing interval 368640-399360: integer division or modulo by zero
# Error processing interval 399360-430080: integer division or modulo by zero
# Error processing interval 430080-460800: integer division or modulo by zero
# Error processing interval 460800-491520: integer division or modulo by zero
# Error processing interval 491520-522240: integer division or modulo by zero
# Error processing interval 522240-552960: integer division or modulo by zero
# Error processing interval 552960-583680: integer division or modulo by zero
# Error processing interval 583680-614400: integer division or modulo by zero
# Error processing interval 614400-645120: cannot convert float NaN to integer
# Error processing interval 645120-675840: integer division or modulo by zero
# Error processing interval 675840-706560: integer division or modulo by zero
# Error processing interval 706560-737280: integer division or modulo by zero
# Error processing interval 737280-768000: cannot convert float NaN to integer
# Error processing interval 768000-798720: integer division or modulo by zero
# Error processing interval 798720-829440: integer division or modulo by zero
# Error processing interval 829440-860160: cannot convert float NaN to integer
# Error processing interval 860160-890880: integer division or modulo by zero
# Number of intervals for fp13_3.csv: 1
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# ECG duration for fp14_1.csv: 3906.73828125 seconds
# Number of intervals for fp14_1.csv: 32
# ECG duration for fp14_2.csv: 3570.578125 seconds
# Number of intervals for fp14_2.csv: 29
# ECG duration for fp14_3.csv: 4214.078125 seconds
# Number of intervals for fp14_3.csv: 35
# ECG duration for fp14_4.csv: 3570.703125 seconds
# Number of intervals for fp14_4.csv: 29
# ECG duration for fp15_1.csv: 3671.453125 seconds
# Number of intervals for fp15_1.csv: 30
# ECG duration for fp15_2.csv: 3574.453125 seconds
# Number of intervals for fp15_2.csv: 29
# ECG duration for fp15_3.csv: 3574.703125 seconds
# Number of intervals for fp15_3.csv: 29
# ECG duration for fp15_4.csv: 3574.453125 seconds
# Number of intervals for fp15_4.csv: 29
# ECG duration for fp16_1.csv: 3829.703125 seconds
# Number of intervals for fp16_1.csv: 31
# ECG duration for fp16_2.csv: 3575.95703125 seconds
# Number of intervals for fp16_2.csv: 29
# ECG duration for fp16_3.csv: 3571.828125 seconds
# Number of intervals for fp16_3.csv: 29
# ECG duration for fp16_4.csv: 3572.453125 seconds
# Number of intervals for fp16_4.csv: 29
# ECG duration for fp17_1.csv: 3639.70703125 seconds
# Number of intervals for fp17_1.csv: 30
# ECG duration for fp17_2.csv: 3823.578125 seconds
# Number of intervals for fp17_2.csv: 31
# ECG duration for fp17_3.csv: 3574.828125 seconds
# Number of intervals for fp17_3.csv: 29
# ECG duration for fp17_4.csv: 3743.70703125 seconds
# Number of intervals for fp17_4.csv: 31
# ECG duration for fp18_1.csv: 3813.328125 seconds
# Number of intervals for fp18_1.csv: 31
# ECG duration for fp18_2.csv: 4069.453125 seconds
# Number of intervals for fp18_2.csv: 33
# ECG duration for fp18_3.csv: 3573.203125 seconds
# Number of intervals for fp18_3.csv: 29
# ECG duration for fp18_4.csv: 3573.078125 seconds
# Number of intervals for fp18_4.csv: 29
# ECG duration for fp19_1.csv: 3639.703125 seconds
# Error processing interval 0-30720: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 61440-92160: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 92160-122880: cannot convert float NaN to integer
# Error processing interval 122880-153600: cannot convert float NaN to integer
# Error processing interval 153600-184320: cannot convert float NaN to integer
# Error processing interval 184320-215040: cannot convert float NaN to integer
# Error processing interval 215040-245760: cannot convert float NaN to integer
# Error processing interval 245760-276480: cannot convert float NaN to integer
# Error processing interval 276480-307200: cannot convert float NaN to integer
# Error processing interval 307200-337920: cannot convert float NaN to integer
# Error processing interval 337920-368640: integer division or modulo by zero
# Error processing interval 368640-399360: cannot convert float NaN to integer
# Error processing interval 399360-430080: cannot convert float NaN to integer
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Error processing interval 430080-460800: index 10 is out of bounds for axis 0 with size 9
# Error processing interval 460800-491520: cannot convert float NaN to integer
# Error processing interval 491520-522240: cannot convert float NaN to integer
# Error processing interval 522240-552960: cannot convert float NaN to integer
# Error processing interval 552960-583680: cannot convert float NaN to integer
# Error processing interval 583680-614400: integer division or modulo by zero
# Error processing interval 614400-645120: cannot convert float NaN to integer
# Error processing interval 645120-675840: cannot convert float NaN to integer
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Error processing interval 675840-706560: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 706560-737280: cannot convert float NaN to integer
# Error processing interval 737280-768000: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 768000-798720: cannot convert float NaN to integer
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Number of intervals for fp19_1.csv: 5
# ECG duration for fp19_2.csv: 3582.71484375 seconds
# Number of intervals for fp19_2.csv: 29
# ECG duration for fp19_3.csv: 3015.7578125 seconds
# Number of intervals for fp19_3.csv: 25
# ECG duration for fp20_1.csv: 3712.078125 seconds
# Number of intervals for fp20_1.csv: 30
# ECG duration for fp20_2.csv: 3577.953125 seconds
# Number of intervals for fp20_2.csv: 29
# ECG duration for fp20_3.csv: 3045.82421875 seconds
# Number of intervals for fp20_3.csv: 25
# ECG duration for fp20_4.csv: 3628.453125 seconds
# Number of intervals for fp20_4.csv: 30

# %% [markdown]
# ## Save Features Dataset CSV

# %%
# Concatenate all feature DataFrames into one DataFrame
all_features_df = pd.concat(feature_dfs, ignore_index=True)

# Save the features DataFrame to a CSV file
all_features_df.to_csv('hrv_time_domain_2_min_filtered.csv', index=False)

print("Saved features on 'hrv_time_domain_2_min_filtered.csv'.")
# Out:
# Saved features on 'hrv_time_domain_2_min_filtered.csv'.
