# %%
import numpy as np
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import neurokit2 as nk
import pyedflib
import pandas as pd
import os

# %% [markdown]
# ## Data

# %%
# directory of EDF files
#edf_directory = '../datasetsPart2/valu3s/vitaport/'
edf_directory = '../datasets_3/DROZY/psg/'

# %%
# path of .csv files
csv_directory = '../datasets_2/valu3s/vitaport/filtered_signals/'

# %%
# duration of each interval in seconds
interval_duration = 60 

# initialize an empty df to store all features
feature_dfs = []

# sampling Rate
#sampling_rate = 256
sampling_rate = 512

# %% [markdown]
# ## Process Freq Domain ECG

# %%
# function extract featrures from ECG
def extract_hrv_features(signal, sampling_rate, interval_duration):
    # number of intrevals
    interval_samples = int(interval_duration * sampling_rate)
    features = [] 
    
    # loop to extract features for each intreval 
    for start in range(0, len(signal), interval_samples):
        end = start + interval_samples
        if end > len(signal):
            break
        
        interval_signal = signal[start:end]
        if len(interval_signal) < interval_samples:
            continue
        
        try:
            # extract features 
            signals, info = nk.ecg_process(interval_signal, sampling_rate=sampling_rate)
            hrv_features = nk.hrv_frequency(info['ECG_R_Peaks'], sampling_rate=sampling_rate, normalize=True)
            hrv_features['Interval_Start'] = start / sampling_rate
            hrv_features['Interval_End'] = end / sampling_rate

            # add extrated features to the DataFrame
            features.append(hrv_features)
        except Exception as e:
            print(f"Error processing interval {start}-{end}: {e}")
            continue

    return features

# loop through all .edf files in the directory
for filename in os.listdir(edf_directory):
    if filename.endswith('.edf'):
        file_path = os.path.join(edf_directory, filename)
        
        # load the .edf file
        f = pyedflib.EdfReader(file_path)
        
        # get signal labels and find ECG signal index
        signal_labels = f.getSignalLabels()
        if 'ECG' in signal_labels:
            ecg_signal_index = signal_labels.index('ECG')
            ecg_signal = f.readSignal(ecg_signal_index)
            sampling_rate = f.getSampleFrequency(ecg_signal_index)
        else:
            print(f"No ECG signal found in {filename}")
            continue
        
        # close the EDF file
        f.close()

        # duration of the ECG signal in seconds
        ecg_duration = len(ecg_signal) / sampling_rate
        print(f"ECG duration for {filename}: {ecg_duration} seconds")
        
        # extract HRV features for each interval
        interval_features = extract_hrv_features(ecg_signal, sampling_rate, interval_duration)

        # number of intervals
        num_intervals = len(interval_features)
        print(f"Number of intervals for {filename}: {num_intervals}")
        
        if interval_features:
            # convert list of feature dictionaries to DataFrame and add filename
            interval_features_df = pd.concat([pd.DataFrame(features) for features in interval_features])
            interval_features_df['Filename'] = filename
        
            # append the features DataFrame to the list
            feature_dfs.append(interval_features_df)
        else:
            print(f"No valid intervals found in {filename}")
# Out:
# ECG duration for 1-1.edf: 600.0 seconds
# Number of intervals for 1-1.edf: 10
# ECG duration for 1-2.edf: 600.0 seconds
# Number of intervals for 1-2.edf: 10
# ECG duration for 1-3.edf: 600.0 seconds
# Number of intervals for 1-3.edf: 10
# ECG duration for 10-1.edf: 600.0 seconds
# Number of intervals for 10-1.edf: 10
# ECG duration for 10-3.edf: 600.0 seconds
# Number of intervals for 10-3.edf: 10
# ECG duration for 11-1.edf: 600.0 seconds
# Number of intervals for 11-1.edf: 10
# ECG duration for 11-2.edf: 600.0 seconds
# Number of intervals for 11-2.edf: 10
# ECG duration for 11-3.edf: 600.0 seconds
# Number of intervals for 11-3.edf: 10
# ECG duration for 12-1.edf: 600.0 seconds
# Number of intervals for 12-1.edf: 10
# ECG duration for 13-1.edf: 600.0 seconds
# Number of intervals for 13-1.edf: 10
# ECG duration for 13-2.edf: 600.0 seconds
# Number of intervals for 13-2.edf: 10
# ECG duration for 14-1.edf: 600.0 seconds
# Number of intervals for 14-1.edf: 10
# ECG duration for 14-2.edf: 600.0 seconds
# Number of intervals for 14-2.edf: 10
# ECG duration for 14-3.edf: 600.0 seconds
# Number of intervals for 14-3.edf: 10
# ECG duration for 2-1.edf: 600.0 seconds
# Number of intervals for 2-1.edf: 10
# ECG duration for 2-2.edf: 600.0 seconds
# Number of intervals for 2-2.edf: 10
# ECG duration for 2-3.edf: 600.0 seconds
# Number of intervals for 2-3.edf: 10
# ECG duration for 3-1.edf: 600.0 seconds
# Number of intervals for 3-1.edf: 10
# ECG duration for 3-2.edf: 600.0 seconds
# Number of intervals for 3-2.edf: 10
# ECG duration for 3-3.edf: 600.0 seconds
# Number of intervals for 3-3.edf: 10
# ECG duration for 4-1.edf: 600.0 seconds
# Number of intervals for 4-1.edf: 10
# ECG duration for 4-2.edf: 600.0 seconds
# Number of intervals for 4-2.edf: 10
# ECG duration for 4-3.edf: 600.0 seconds
# Number of intervals for 4-3.edf: 10
# ECG duration for 5-1.edf: 600.0 seconds
# Number of intervals for 5-1.edf: 10
# ECG duration for 5-2.edf: 600.0 seconds
# Number of intervals for 5-2.edf: 10
# ECG duration for 5-3.edf: 600.0 seconds
# Number of intervals for 5-3.edf: 10
# ECG duration for 6-1.edf: 600.0 seconds
# Number of intervals for 6-1.edf: 10
# ECG duration for 6-2.edf: 600.0 seconds
# Number of intervals for 6-2.edf: 10
# ECG duration for 6-3.edf: 600.0 seconds
# Number of intervals for 6-3.edf: 10
# ECG duration for 7-2.edf: 600.0 seconds
# Number of intervals for 7-2.edf: 10
# ECG duration for 7-3.edf: 600.0 seconds
# Number of intervals for 7-3.edf: 10
# ECG duration for 8-1.edf: 600.0 seconds
# Number of intervals for 8-1.edf: 10
# ECG duration for 8-2.edf: 600.0 seconds
# Number of intervals for 8-2.edf: 10
# ECG duration for 8-3.edf: 600.0 seconds
# Number of intervals for 8-3.edf: 10
# ECG duration for 9-2.edf: 600.0 seconds
# Number of intervals for 9-2.edf: 10
# ECG duration for 9-3.edf: 600.0 seconds
# Number of intervals for 9-3.edf: 10

# %% [markdown]
# ## Save Features Dataset EDF

# %%
# concatenate all feature DataFrames into one DataFrame
all_features_df = pd.concat(feature_dfs, ignore_index=True)

# save the features DataFrame to a CSV file
all_features_df.to_csv('DROZY_hrv_freq_domain_1_min.csv', index=False)

print("Saved features on 'DROZY_hrv_freq_domain_1_min.csv'.")
# Out:
# Saved features on 'DROZY_hrv_freq_domain_1_min.csv'.

# %% [markdown]
# ## Process Freq Domain CSV

# %%
# function extract featrures from ECG
def extract_hrv_features(signal, sampling_rate, interval_duration):
    # number of intrevals
    start_sample = int(30 * sampling_rate)
    interval_samples = int(interval_duration * sampling_rate)
    features = [] 
    
    # loop to extract features for each intreval 
    for start in range(start_sample, len(signal), interval_samples):
        end = start + interval_samples
        if end > len(signal):
            break
        
        interval_signal = signal[start:end]
        if len(interval_signal) < interval_samples:
            continue
        
        try:
            # extract features 
            signals, info = nk.ecg_process(interval_signal, sampling_rate=sampling_rate)
            hrv_features = nk.hrv_frequency(info['ECG_R_Peaks'], sampling_rate=sampling_rate, normalize=True)
            hrv_features['Interval_Start'] = start / sampling_rate
            hrv_features['Interval_End'] = end / sampling_rate

            # add extrated features to the DataFrame
            features.append(hrv_features)
        except Exception as e:
            print(f"Error processing interval {start}-{end}: {e}")
            continue

    return features

# loop all edf files 
for filename in os.listdir(csv_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(csv_directory, filename)
        
        # load the CSV file 
        try:
            # read CSV 
            df = pd.read_csv(file_path, header=None)
            ecg_signal = df[0].values 
        except Exception as e:
            print(f"Error loading {filename}: {e}")
            continue

        # duration of the ECG signal in seconds
        ecg_duration = len(ecg_signal) / sampling_rate
        print(f"ECG duration for {filename}: {ecg_duration} seconds")
        
        # extract HRV features for each interval
        interval_features = extract_hrv_features(ecg_signal, sampling_rate, interval_duration)

        # number of intervals
        num_intervals = len(interval_features)
        print(f"Number of intervals for {filename}: {num_intervals}")
        
        if interval_features:
            # convert list of feature dictionaries to DataFrame and add filename
            interval_features_df = pd.concat([pd.DataFrame(features) for features in interval_features])
            interval_features_df['Filename'] = filename
        
            # append the features DataFrame to the list
            feature_dfs.append(interval_features_df)
        else:
            print(f"No valid intervals found in {filename}")
# Out:
# ECG duration for fp01_1.csv: 3694.578125 seconds
# Number of intervals for fp01_1.csv: 61
# ECG duration for fp01_2.csv: 3576.703125 seconds
# Number of intervals for fp01_2.csv: 59
# ECG duration for fp01_3.csv: 3574.078125 seconds
# Number of intervals for fp01_3.csv: 59
# ECG duration for fp01_4.csv: 3734.52734375 seconds
# Number of intervals for fp01_4.csv: 61
# ECG duration for fp02_1.csv: 3721.453125 seconds
# Number of intervals for fp02_1.csv: 61
# ECG duration for fp02_2.csv: 3691.203125 seconds
# Number of intervals for fp02_2.csv: 61
# ECG duration for fp02_3.csv: 3575.078125 seconds
# Number of intervals for fp02_3.csv: 59
# ECG duration for fp02_4.csv: 3668.953125 seconds
# Number of intervals for fp02_4.csv: 60
# ECG duration for fp03_2.csv: 3990.5078125 seconds
# Number of intervals for fp03_2.csv: 66
# ECG duration for fp03_3.csv: 3580.953125 seconds
# Number of intervals for fp03_3.csv: 59
# ECG duration for fp03_4.csv: 3573.328125 seconds
# Number of intervals for fp03_4.csv: 59
# ECG duration for fp04_1.csv: 3983.578125 seconds
# Number of intervals for fp04_1.csv: 65
# ECG duration for fp04_2.csv: 3580.703125 seconds
# Number of intervals for fp04_2.csv: 59
# ECG duration for fp04_3.csv: 3570.828125 seconds
# Number of intervals for fp04_3.csv: 59
# ECG duration for fp04_4.csv: 3575.203125 seconds
# Number of intervals for fp04_4.csv: 59
# ECG duration for fp05_1.csv: 3891.828125 seconds
# Number of intervals for fp05_1.csv: 64
# ECG duration for fp05_2.csv: 3574.328125 seconds
# Number of intervals for fp05_2.csv: 59
# ECG duration for fp05_3.csv: 3606.7578125 seconds
# Number of intervals for fp05_3.csv: 59
# ECG duration for fp05_4.csv: 3573.203125 seconds
# Number of intervals for fp05_4.csv: 59
# ECG duration for fp06_1.csv: 4004.453125 seconds
# Number of intervals for fp06_1.csv: 66
# ECG duration for fp06_2.csv: 3574.953125 seconds
# Number of intervals for fp06_2.csv: 59
# ECG duration for fp06_3.csv: 3572.328125 seconds
# Number of intervals for fp06_3.csv: 59
# ECG duration for fp06_4.csv: 3572.578125 seconds
# Number of intervals for fp06_4.csv: 59
# ECG duration for fp07_1.csv: 3698.453125 seconds
# Number of intervals for fp07_1.csv: 61
# ECG duration for fp07_2.csv: 3606.5078125 seconds
# Number of intervals for fp07_2.csv: 59
# ECG duration for fp07_3.csv: 3578.328125 seconds
# Number of intervals for fp07_3.csv: 59
# ECG duration for fp07_4.csv: 3582.453125 seconds
# Number of intervals for fp07_4.csv: 59
# ECG duration for fp08_1.csv: 3938.953125 seconds
# Number of intervals for fp08_1.csv: 65
# ECG duration for fp08_2.csv: 3571.828125 seconds
# Number of intervals for fp08_2.csv: 59
# ECG duration for fp08_3.csv: 3572.078125 seconds
# Number of intervals for fp08_3.csv: 59
# ECG duration for fp08_4.csv: 3571.328125 seconds
# Number of intervals for fp08_4.csv: 59
# ECG duration for fp09_1.csv: 3876.078125 seconds
# Error processing interval 7680-23040: index 0 is out of bounds for axis 0 with size 0
# Number of intervals for fp09_1.csv: 63
# ECG duration for fp09_2.csv: 3569.078125 seconds
# Number of intervals for fp09_2.csv: 58
# ECG duration for fp09_3.csv: 3574.953125 seconds
# Number of intervals for fp09_3.csv: 59
# ECG duration for fp09_4.csv: 3577.203125 seconds
# Number of intervals for fp09_4.csv: 59
# ECG duration for fp10_1.csv: 3789.453125 seconds
# Number of intervals for fp10_1.csv: 62
# ECG duration for fp10_2.csv: 3579.20703125 seconds
# Number of intervals for fp10_2.csv: 59
# ECG duration for fp10_3.csv: 3575.703125 seconds
# Number of intervals for fp10_3.csv: 59
# ECG duration for fp10_4.csv: 3570.578125 seconds
# Number of intervals for fp10_4.csv: 59
# ECG duration for fp11_1.csv: 3718.078125 seconds
# Number of intervals for fp11_1.csv: 61
# ECG duration for fp11_2.csv: 3573.828125 seconds
# Number of intervals for fp11_2.csv: 59
# ECG duration for fp11_3.csv: 3573.703125 seconds
# Number of intervals for fp11_3.csv: 59
# ECG duration for fp11_4.csv: 3575.703125 seconds
# Number of intervals for fp11_4.csv: 59
# ECG duration for fp12_1.csv: 3835.703125 seconds
# Number of intervals for fp12_1.csv: 63
# ECG duration for fp12_2.csv: 3576.578125 seconds
# Number of intervals for fp12_2.csv: 59
# ECG duration for fp12_3.csv: 3572.828125 seconds
# Number of intervals for fp12_3.csv: 59
# ECG duration for fp12_4.csv: 3578.328125 seconds
# Number of intervals for fp12_4.csv: 59
# ECG duration for fp13_1.csv: 3860.453125 seconds
# Error processing interval 7680-23040: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 23040-38400: index 9 is out of bounds for axis 0 with size 9
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Error processing interval 69120-84480: cannot convert float NaN to integer
# Error processing interval 84480-99840: cannot convert float NaN to integer
# Error processing interval 99840-115200: cannot convert float NaN to integer
# Error processing interval 115200-130560: cannot convert float NaN to integer
# Error processing interval 130560-145920: integer division or modulo by zero
# Error processing interval 145920-161280: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 161280-176640: integer division or modulo by zero
# Error processing interval 176640-192000: integer division or modulo by zero
# Error processing interval 192000-207360: integer division or modulo by zero
# Error processing interval 207360-222720: integer division or modulo by zero
# Error processing interval 222720-238080: integer division or modulo by zero
# Error processing interval 238080-253440: integer division or modulo by zero
# Error processing interval 253440-268800: integer division or modulo by zero
# Error processing interval 268800-284160: integer division or modulo by zero
# Error processing interval 284160-299520: integer division or modulo by zero
# Error processing interval 299520-314880: integer division or modulo by zero
# Error processing interval 314880-330240: integer division or modulo by zero
# Error processing interval 330240-345600: integer division or modulo by zero
# Error processing interval 345600-360960: integer division or modulo by zero
# Error processing interval 360960-376320: integer division or modulo by zero
# Error processing interval 376320-391680: integer division or modulo by zero
# Error processing interval 391680-407040: integer division or modulo by zero
# Error processing interval 407040-422400: integer division or modulo by zero
# Error processing interval 422400-437760: integer division or modulo by zero
# Error processing interval 437760-453120: integer division or modulo by zero
# Error processing interval 453120-468480: integer division or modulo by zero
# Error processing interval 468480-483840: integer division or modulo by zero
# Error processing interval 483840-499200: integer division or modulo by zero
# Error processing interval 499200-514560: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 514560-529920: integer division or modulo by zero
# Error processing interval 529920-545280: integer division or modulo by zero
# Error processing interval 545280-560640: integer division or modulo by zero
# Error processing interval 560640-576000: integer division or modulo by zero
# Error processing interval 576000-591360: integer division or modulo by zero
# Error processing interval 591360-606720: integer division or modulo by zero
# Error processing interval 606720-622080: integer division or modulo by zero
# Error processing interval 622080-637440: integer division or modulo by zero
# Error processing interval 637440-652800: index 0 is out of bounds for axis 0 with size 0
# Error processing interval 652800-668160: integer division or modulo by zero
# Error processing interval 668160-683520: integer division or modulo by zero
# Error processing interval 683520-698880: integer division or modulo by zero
# Error processing interval 698880-714240: integer division or modulo by zero
# Error processing interval 714240-729600: integer division or modulo by zero
# Error processing interval 729600-744960: integer division or modulo by zero
# Error processing interval 744960-760320: integer division or modulo by zero
# Error processing interval 760320-775680: integer division or modulo by zero
# Error processing interval 775680-791040: integer division or modulo by zero
# Error processing interval 791040-806400: integer division or modulo by zero
# Error processing interval 806400-821760: integer division or modulo by zero
# Error processing interval 821760-837120: integer division or modulo by zero
# Error processing interval 837120-852480: integer division or modulo by zero
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# ...
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Error processing interval 69120-84480: cannot convert float NaN to integer
# Error processing interval 84480-99840: cannot convert float NaN to integer
# Error processing interval 99840-115200: integer division or modulo by zero
# Error processing interval 115200-130560: integer division or modulo by zero
# Error processing interval 130560-145920: cannot convert float NaN to integer
# Error processing interval 145920-161280: integer division or modulo by zero
# Error processing interval 161280-176640: cannot convert float NaN to integer
# Error processing interval 176640-192000: cannot convert float NaN to integer
# Error processing interval 192000-207360: cannot convert float NaN to integer
# Error processing interval 207360-222720: cannot convert float NaN to integer
# Error processing interval 222720-238080: integer division or modulo by zero
# Error processing interval 238080-253440: cannot convert float NaN to integer
# Error processing interval 253440-268800: cannot convert float NaN to integer
# Error processing interval 268800-284160: cannot convert float NaN to integer
# Error processing interval 284160-299520: integer division or modulo by zero
# Error processing interval 299520-314880: cannot convert float NaN to integer
# Error processing interval 314880-330240: integer division or modulo by zero
# Error processing interval 330240-345600: cannot convert float NaN to integer
# Error processing interval 345600-360960: integer division or modulo by zero
# Error processing interval 360960-376320: integer division or modulo by zero
# Error processing interval 376320-391680: cannot convert float NaN to integer
# Error processing interval 391680-407040: integer division or modulo by zero
# Error processing interval 407040-422400: cannot convert float NaN to integer
# Error processing interval 422400-437760: cannot convert float NaN to integer
# Error processing interval 437760-453120: cannot convert float NaN to integer
# Error processing interval 453120-468480: integer division or modulo by zero
# Error processing interval 468480-483840: cannot convert float NaN to integer
# Error processing interval 483840-499200: cannot convert float NaN to integer
# Error processing interval 499200-514560: cannot convert float NaN to integer
# Error processing interval 514560-529920: integer division or modulo by zero
# Error processing interval 529920-545280: integer division or modulo by zero
# Error processing interval 545280-560640: cannot convert float NaN to integer
# Error processing interval 560640-576000: cannot convert float NaN to integer
# Error processing interval 576000-591360: cannot convert float NaN to integer
# Error processing interval 591360-606720: integer division or modulo by zero
# Error processing interval 606720-622080: cannot convert float NaN to integer
# Error processing interval 622080-637440: integer division or modulo by zero
# Error processing interval 637440-652800: cannot convert float NaN to integer
# Error processing interval 652800-668160: cannot convert float NaN to integer
# Error processing interval 668160-683520: cannot convert float NaN to integer
# Error processing interval 683520-698880: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 698880-714240: cannot convert float NaN to integer
# Error processing interval 714240-729600: cannot convert float NaN to integer
# Error processing interval 729600-744960: cannot convert float NaN to integer
# Error processing interval 744960-760320: cannot convert float NaN to integer
# Error processing interval 760320-775680: index 9 is out of bounds for axis 0 with size 9
# Error processing interval 775680-791040: integer division or modulo by zero
# Error processing interval 791040-806400: cannot convert float NaN to integer
# Error processing interval 806400-821760: cannot convert float NaN to integer
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\duart\AppData\Local\Programs\Python\Python39\lib\site-packages\neurokit2\signal\signal_period.py:84: NeuroKitWarning: Too few peaks detected to compute the rate. Returning empty vector.
#   warn(
# Number of intervals for fp19_1.csv: 9
# ECG duration for fp19_2.csv: 3582.71484375 seconds
# Number of intervals for fp19_2.csv: 59
# ECG duration for fp19_3.csv: 3015.7578125 seconds
# Number of intervals for fp19_3.csv: 49
# ECG duration for fp20_1.csv: 3712.078125 seconds
# Number of intervals for fp20_1.csv: 61
# ECG duration for fp20_2.csv: 3577.953125 seconds
# Number of intervals for fp20_2.csv: 59
# ECG duration for fp20_3.csv: 3045.82421875 seconds
# Number of intervals for fp20_3.csv: 50
# ECG duration for fp20_4.csv: 3628.453125 seconds
# Number of intervals for fp20_4.csv: 59

# %% [markdown]
# ## Save Features Dataset EDF

# %%
# concatenate all feature DataFrames into one DataFrame
all_features_df = pd.concat(feature_dfs, ignore_index=True)

# save the features DataFrame to a CSV file
all_features_df.to_csv('freq_domain_1_min_overlap.csv', index=False)

print("Saved features on 'freq_domain_1_min_overlap.csv'.")
# Out:
# Saved features on 'freq_domain_1_min_overlap.csv'.
